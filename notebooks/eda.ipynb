# %%
# Imports
import pandas as pd
# Load data
df = pd.read_csv("../data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
# Preview data
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# **What is one row?**
# - One row = one customer
#
# **So if one row is one customer:**
# 1. How many customers do we have?
# 2. Can a customer appear more than once?

# %%
print(f"Number of customers = {df.shape[0]}")
print(f"Number of features = {df.shape[1]}")
print(f"number of duplicated rows = {df.duplicated().sum()}")
print(f"number of duplicated customer IDs = {df['customerID'].duplicated().sum()}")
print(f"what are the customerID = {df['customerID'].unique()}")
print(f"Missing customerID: {df['customerID'].isna().sum()}")
print(f"what are the outputs = {df['Churn'].unique()}")
print(df["Churn"].value_counts(dropna=False))
print(df["Churn"].value_counts(dropna=False).sum())
# Out:
# Number of customers = 7043
# Number of features = 21
# number of duplicated rows = 0
# number of duplicated customer IDs = 0
# what are the customerID = <StringArray>
# ['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', '7795-CFOCW', '9237-HQITU',
#  '9305-CDSKC', '1452-KIOVK', '6713-OKOMC', '7892-POOKP', '6388-TABGU',
#  ...
#  '9767-FFLEM', '0639-TSIQW', '8456-QDAVC', '7750-EYXWZ', '2569-WGERO',
#  '6840-RESVB', '2234-XADUH', '4801-JZAZL', '8361-LTMKD', '3186-AJIEK']
# Length: 7043, dtype: str
# Missing customerID: 0
# what are the outputs = <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
# 7043

# %% [markdown]
# **It's a supervised binary classification problem**
#
# - We have output -> Supervised
#
# - The output is either Yes or No -> binary
#
# - Want to predict if a customer churn or not -> Classification
#
# **customerID**
#
# - No missing values.
# - No duplicated customer IDs.
# - Number of unique IDs equals the number of rows, so each row represents a unique customer.
# - No cleaning is required.
# - `customerID` is an identifier and should not be used as a predictive feature.

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
# This will show us if we have any missing values and the data types of each column
# If there is a missing value, we will have to decide how to handle it. We can either drop the rows with missing values or fill them with a default value.
# We should check if the data types are correct. For example, if a column is supposed to be numeric but is stored as a string, we will have to convert it to the correct data type.
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
print("gender", df['gender'].unique(), "\n")
print(df["gender"].value_counts(dropna=False))
print(df["gender"].value_counts(dropna=False).sum())

print("SeniorCitizen", df['SeniorCitizen'].unique(), "\n")
print(df["SeniorCitizen"].value_counts(dropna=False))
print(df["SeniorCitizen"].value_counts(dropna=False).sum())

print("Partner", df['Partner'].unique(), "\n")
print(df["Partner"].value_counts(dropna=False))
print(df["Partner"].value_counts(dropna=False).sum())

print("Dependents", df['Dependents'].unique(), "\n")
print(df["Dependents"].value_counts(dropna=False))
print(df["Dependents"].value_counts(dropna=False).sum())

print("tenure", df['tenure'].unique(), "\n")
print(df["tenure"].value_counts(dropna=False))
print(df["tenure"].value_counts(dropna=False).sum())

print("PhoneService", df['PhoneService'].unique(), "\n")
print(df["PhoneService"].value_counts(dropna=False))
print(df["PhoneService"].value_counts(dropna=False).sum())

print("MultipleLines", df['MultipleLines'].unique(), "\n")
print(df["MultipleLines"].value_counts(dropna=False))
print(df["MultipleLines"].value_counts(dropna=False).sum())

print("InternetService", df['InternetService'].unique(), "\n")
print(df["InternetService"].value_counts(dropna=False))
print(df["InternetService"].value_counts(dropna=False).sum())

print("OnlineSecurity", df['OnlineSecurity'].unique(), "\n")
print(df["OnlineSecurity"].value_counts(dropna=False))
print(df["OnlineSecurity"].value_counts(dropna=False).sum())

print("OnlineBackup", df['OnlineBackup'].unique(), "\n")
print(df["OnlineBackup"].value_counts(dropna=False))
print(df["OnlineBackup"].value_counts(dropna=False).sum())

print("DeviceProtection", df['DeviceProtection'].unique(), "\n")
print(df["DeviceProtection"].value_counts(dropna=False))
print(df["DeviceProtection"].value_counts(dropna=False).sum())

print("TechSupport", df['TechSupport'].unique(), "\n")
print(df["TechSupport"].value_counts(dropna=False))
print(df["TechSupport"].value_counts(dropna=False).sum())

print("StreamingTV", df['StreamingTV'].unique(), "\n")
print(df["StreamingTV"].value_counts(dropna=False))
print(df["StreamingTV"].value_counts(dropna=False).sum())

print("StreamingMovies", df['StreamingMovies'].unique(), "\n")
print(df["StreamingMovies"].value_counts(dropna=False))
print(df["StreamingMovies"].value_counts(dropna=False).sum())

print("Contract", df['Contract'].unique(), "\n")
print(df["Contract"].value_counts(dropna=False))
print(df["Contract"].value_counts(dropna=False).sum())

print("PaperlessBilling", df['PaperlessBilling'].unique(), "\n")
print(df["PaperlessBilling"].value_counts(dropna=False))
print(df["PaperlessBilling"].value_counts(dropna=False).sum())

print("PaymentMethod", df['PaymentMethod'].unique(), "\n")
print(df["PaymentMethod"].value_counts(dropna=False))
print(df["PaymentMethod"].value_counts(dropna=False).sum())

print("MonthlyCharges", df['MonthlyCharges'].unique(), "\n")
print(df["MonthlyCharges"].value_counts(dropna=False))
print(df["MonthlyCharges"].value_counts(dropna=False).sum())

print("TotalCharges", df['TotalCharges'].unique(), "\n")
print(df["TotalCharges"].value_counts(dropna=False))
print(df["TotalCharges"].value_counts(dropna=False).sum())
# Out:
# gender <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
# 7043
# SeniorCitizen [0 1]
#
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
# 7043
# Partner <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
# 7043
# Dependents <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
# 7043
# tenure [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
#
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
# 7043
# PhoneService <StringArray>
# ...

# %% [markdown]
# **As we can see, SeniorCitizen should be a boolean, and TotalCharges should be a float.**
#
# What values inside TotalCharges are preventing pandas from treating the entire column as numeric?

# %%
total_charges_numeric = pd.to_numeric(df["TotalCharges"], errors="coerce")
mask = total_charges_numeric.isna()
df.loc[mask]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
df.loc[df["tenure"] == 0]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
(df.loc[mask, "tenure"] == 0).all()
# Out:
# np.True_

# %% [markdown]
# So we can see when "tenure" == 0, then total charges is "" which makes sence.

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# Now I want to check if there is a same problem with other columns:

# %%
string_columns = df.select_dtypes(include=["object", "string"]).columns

for col in string_columns:
    blank_count = df[col].str.strip().eq("").sum()

    if blank_count > 0:
        print(f"{col}: {blank_count} blank values")
# Out:
# TotalCharges: 11 blank values

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# So the data is inbalence and we should consider it when we want to evaluate the model.

# %%
print(df.loc[df["PhoneService"] == "No", "MultipleLines"].value_counts())
print(df.loc[df["MultipleLines"] == "No phone service", "PhoneService"].value_counts())
internet_features = [
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
]

for col in internet_features:
    print(col)
    print(df.loc[df["InternetService"] == "No", col].value_counts(), "\n")
# Out:
# MultipleLines
# No phone service    682
# Name: count, dtype: int64
# PhoneService
# No    682
# Name: count, dtype: int64
# OnlineSecurity
# OnlineSecurity
# No internet service    1526
# Name: count, dtype: int64
#
# OnlineBackup
# OnlineBackup
# No internet service    1526
# Name: count, dtype: int64
#
# DeviceProtection
# DeviceProtection
# No internet service    1526
# Name: count, dtype: int64
#
# TechSupport
# TechSupport
# No internet service    1526
# Name: count, dtype: int64
#
# StreamingTV
# StreamingTV
# No internet service    1526
# Name: count, dtype: int64
#
# StreamingMovies
# StreamingMovies
# No internet service    1526
# Name: count, dtype: int64
